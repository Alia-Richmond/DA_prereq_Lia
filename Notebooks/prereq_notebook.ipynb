# %%
print ("Hello , My name is Lia")

# %% [markdown]
# Hi, my name is Alia, but I go by Lia. I currently work in technical support and I'm transitioning into data analytics. I'm excited to learn how to work with data and use it to grow in my career.
